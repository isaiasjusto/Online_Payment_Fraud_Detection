# %% [markdown]
# # Pagamentos Fraudulentos
# <b> O pagamento online é o método de transação mais popular no mundo hoje. No entanto, com o aumento dos pagamentos online, também vem o aumento da fraude de pagamento. O objetivo deste estudo é identificar pagamentos fraudulentos e não fraudulentos. O conjunto de dados é coletado do Kaggle, que contém informações históricas sobre transações fraudulentas que podem ser usadas para detectar fraudes em pagamentos online. </b>
#
# The dataset consists of 10 variables:
#
# step: represents a unit of time where 1 step equals 1 hour
# type: type of online transaction
# amount: the amount of the transaction
# nameOrig: customer starting the transaction
# oldbalanceOrg: balance before the transaction
# newbalanceOrig: balance after the transaction
# nameDest: recipient of the transaction
# oldbalanceDest: initial balance of recipient before the transaction
# newbalanceDest: the new balance of recipient after the transaction
# isFraud: fraud transaction

# %% [markdown]
# ## Importações

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from matplotlib.colors import LinearSegmentedColormap

# %% [markdown]
# ## <b> EDA  </b>

# %%
df = pd.read_csv('onlinefraud.csv')
df.drop('isFlaggedFraud', axis=1, inplace=True)

# %%
for col in df.columns:
    if df[col].dtype == 'float64':
        df[col] = pd.to_numeric(df[col], downcast='float')
    if df[col].dtype == 'int64':
        df[col] = pd.to_numeric(df[col], downcast='unsigned')

# Use category dtype for categorical column
df['type'] = df['type'].astype('category')

# %%
df.sample(5)
# Out:
#          step      type     amount     nameOrig  oldbalanceOrg  \
# 4621405   329   CASH_IN  108863.56   C824423362        16416.0
# 1810494   163  CASH_OUT   20642.25   C917635367            0.0
# 4876434   348   PAYMENT   26186.77  C1365986768        50264.0
# 2264163   187  CASH_OUT  128890.99   C566665870            0.0
# 3702706   277   PAYMENT    7828.95   C437981156        13877.0
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud
# 4621405       125279.56  C1643980866       605188.18       496324.62        0
# 1810494            0.00  C1831802199        50583.98        71226.23        0
# 4876434        24077.23  M1746423704            0.00            0.00        0
# 2264163            0.00  C1090398096      1418405.35      1547296.34        0
# 3702706         6048.05   M489978654            0.00            0.00        0

# %%
df.isnull().sum()
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#                step        amount  oldbalanceOrg  newbalanceOrig  \
# count  6.362620e+06  6.362620e+06   6.362620e+06    6.362620e+06
# mean   2.433972e+02  1.798619e+05   8.338831e+05    8.551137e+05
# std    1.423320e+02  6.038582e+05   2.888243e+06    2.924049e+06
# min    1.000000e+00  0.000000e+00   0.000000e+00    0.000000e+00
# 25%    1.560000e+02  1.338957e+04   0.000000e+00    0.000000e+00
# 50%    2.390000e+02  7.487194e+04   1.420800e+04    0.000000e+00
# 75%    3.350000e+02  2.087215e+05   1.073152e+05    1.442584e+05
# max    7.430000e+02  9.244552e+07   5.958504e+07    4.958504e+07
#
#        oldbalanceDest  newbalanceDest       isFraud
# count    6.362620e+06    6.362620e+06  6.362620e+06
# mean     1.100702e+06    1.224996e+06  1.290820e-03
# std      3.399180e+06    3.674129e+06  3.590480e-02
# min      0.000000e+00    0.000000e+00  0.000000e+00
# 25%      0.000000e+00    0.000000e+00  0.000000e+00
# 50%      1.327057e+05    2.146614e+05  0.000000e+00
# ...

# %% [markdown]
# <b> O fato de Cash Out ser o tipo de transação com o maior valor total (394.412.985.224) sugere que os usuários estão retirando grandes quantias de dinheiro do sistema. Esse comportamento pode indicar que os usuários estão transferindo fundos para contas externas ou convertendo saldos em dinheiro físico, seja para uso pessoal ou para outras finalidades. Transações de alto valor, como saques de investimentos, pagamentos de salários ou transferências para contas pessoais, são comuns nessa categoria, o que justifica o volume significativo.</b>
#
# <b> Além disso, a análise mostra que Cash Out e Cash In são os tipos de transação com o maior número de atividades fraudulentas, com 4.097 e 4.106 casos, respectivamente. No entanto, é importante notar que Transfer, Payment e Debit não apresentaram nenhum caso de fraude nos dados analisados. Embora a proporção de fraudes em relação ao total de transações seja relativamente baixa (0,08% para Cash Out e Cash In), o volume absoluto de fraudes é preocupante. Isso indica que, embora a maioria das transações seja legítima, ainda há um número significativo de atividades fraudulentas que precisam ser monitoradas. </b>
#
# <b> Outro ponto importante é a distribuição dos tipos de transações. O gráfico de pizza revela que Cash Out representa 35,2% do total de transações, seguido por Transfer (33,8%) e Payment (22,0%). Essa distribuição reforça a predominância de Cash Out e Transfer no sistema, tanto em volume de transações quanto em valor total. </b>
#
# <b> Portanto, é essencial monitorar de perto as operações de Cash Out e Cash In para identificar padrões suspeitos, como saques repetidos de alto valor ou transferências para contas desconhecidas. A implementação de medidas de segurança adicionais, como autenticação de dois fatores e alertas em tempo real, pode ajudar a mitigar os riscos associados a essas transações. </b>

# %%
if {'type', 'isFraud', 'amount'}.issubset(df.columns):
    # Gráfico de pizza: Distribuição dos tipos de transações
    transaction_counts = df['type'].value_counts()
    plot_pie_chart(transaction_counts, 'Distribuição dos Tipos de Transações')
    plt.show()

# %%
# Distribuição de transações ao longo do tempo
plt.figure(figsize=(12, 6))
sns.histplot(data=df, x='step', bins=50, hue='isFraud', multiple='stack')
plt.title('Distribuição de Transações ao Longo do Tempo (horas)')
plt.xlabel('Step (1 step = 1 hora)')
plt.ylabel('Contagem de Transações')
plt.show()

# Top horas com maior ocorrência de fraudes
top_fraud_hours = df[df['isFraud'] == 1]['step'].value_counts().head(10)
plt.figure(figsize=(10, 6))
top_fraud_hours.sort_values().plot.barh()
plt.title('Top 10 Horas com Mais Ocorrências de Fraude')
plt.xlabel('Número de Transações Fraudulentas')
plt.ylabel('Step (hora)')
plt.show()

# %%
# Distribuição por tipo de transação
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='type', hue='isFraud')
plt.title('Distribuição de Transações por Tipo')
plt.xlabel('Tipo de Transação')
plt.ylabel('Contagem')
plt.legend(title='isFraud', labels=['Não Fraude', 'Fraude'])
plt.show()

# Taxa de fraude por tipo de transação
fraud_by_type = df.groupby('type')['isFraud'].mean().sort_values(ascending=False) * 100
plt.figure(figsize=(10, 6))
fraud_by_type.plot.bar()
plt.title('Taxa de Fraude por Tipo de Transação (%)')
plt.ylabel('Porcentagem de Transações Fraudulentas')
plt.axhline(y=fraud_ratio, color='r', linestyle='--', label='Taxa Média de Fraude')
plt.legend()
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11420\1786837837.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   fraud_by_type = df.groupby('type')['isFraud'].mean().sort_values(ascending=False) * 100
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 16
#      14 plt.title('Taxa de Fraude por Tipo de Transação (%)')
#      15 plt.ylabel('Porcentagem de Transações Fraudulentas')
# ---> 16 plt.axhline(y=fraud_ratio, color='r', linestyle='--', label='Taxa Média de Fraude')
#      17 plt.legend()
#      18 plt.show()
#
# NameError: name 'fraud_ratio' is not defined

# %%
# Distribuição de valores
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='isFraud', y='amount', showfliers=False)
plt.yscale('log')  # Usando escala log devido à grande variação
plt.title('Distribuição de Valores (log scale) por Status de Fraude')
plt.xlabel('É Fraude?')
plt.ylabel('Valor da Transação (log)')
plt.xticks([0, 1], ['Não', 'Sim'])
plt.show()

# Estatísticas de valores por status de fraude
print("\n" + "="*50)
print("Estatísticas de valores por status de fraude:")
print(df.groupby('isFraud')['amount'].describe())
# Out:
# ...
# Estatísticas de valores por status de fraude:
#              count          mean           std   min         25%        50%  \
# isFraud
# 0        6354407.0  1.781970e+05  5.962370e+05  0.01   13368.395   74684.72
# 1           8213.0  1.467967e+06  2.404253e+06  0.00  127091.330  441423.44
#
#                 75%          max
# isFraud
# 0         208364.76  92445516.64
# 1        1517771.48  10000000.00

# %%
# Criando features adicionais
df['balance_change_orig'] = df['newbalanceOrig'] - df['oldbalanceOrg']
df['balance_change_dest'] = df['newbalanceDest'] - df['oldbalanceDest']

# Análise de mudanças de saldo
fig, axes = plt.subplots(1, 2, figsize=(15, 6))
sns.boxplot(data=df, x='isFraud', y='balance_change_orig', ax=axes[0], showfliers=False)
axes[0].set_title('Mudança no Saldo de Origem')
axes[0].set_xticklabels(['Não', 'Sim'])

sns.boxplot(data=df, x='isFraud', y='balance_change_dest', ax=axes[1], showfliers=False)
axes[1].set_title('Mudança no Saldo de Destino')
axes[1].set_xticklabels(['Não', 'Sim'])

plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11420\2963765177.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0].set_xticklabels(['Não', 'Sim'])
# C:\Users\user\AppData\Local\Temp\ipykernel_11420\2963765177.py:13: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[1].set_xticklabels(['Não', 'Sim'])

# %%
# Estatísticas descritivas detalhadas
amount_stats = df.groupby('isFraud')['amount'].describe(percentiles=[.01, .05, .25, .5, .75, .95, .99])
print("Estatísticas descritivas do valor por status de fraude:")
print(amount_stats)

# Adicionando medidas de dispersão
amount_stats['IQR'] = amount_stats['75%'] - amount_stats['25%']
amount_stats['Coef. Variação'] = amount_stats['std'] / amount_stats['mean']
print("\nEstatísticas com medidas de dispersão:")
print(amount_stats[['mean', 'std', 'IQR', 'Coef. Variação', 'min', 'max']])
# Out:
# Estatísticas descritivas do valor por status de fraude:
#              count          mean           std   min       1%         5%  \
# isFraud
# 0        6354407.0  1.781970e+05  5.962370e+05  0.01   449.24   2221.983
# 1           8213.0  1.467967e+06  2.404253e+06  0.00  1842.00  17484.290
#
#                 25%        50%         75%          95%           99%  \
# isFraud
# 0         13368.395   74684.72   208364.76   515610.423  1.586064e+06
# 1        127091.330  441423.44  1517771.48  8006429.040  1.000000e+07
#
#                  max
# isFraud
# 0        92445516.64
# 1        10000000.00
#
# Estatísticas com medidas de dispersão:
#                  mean           std          IQR  Coef. Variação   min  \
# isFraud
# 0        1.781970e+05  5.962370e+05   194996.365        3.345942  0.01
# 1        1.467967e+06  2.404253e+06  1390680.150        1.637811  0.00
#
#                  max
# isFraud
# 0        92445516.64
# 1        10000000.00

# %% [markdown]
# ## Análise da Distribuição Bimodal

# %%
plt.figure(figsize=(14, 8))

# Plot com escala logarítmica para melhor visualização
plt.subplot(2, 2, 1)
sns.histplot(data=df, x='amount', hue='isFraud', bins=50, element='step', log_scale=True)
plt.title('Distribuição de Valores (Escala Log)')
plt.xlabel('Valor (log)')

# Boxplot sem outliers extremos
plt.subplot(2, 2, 2)
sns.boxplot(data=df[df['amount'] < df['amount'].quantile(0.99)], x='isFraud', y='amount', showfliers=False)
plt.title('Distribuição (99º percentil)')
plt.xticks([0, 1], ['Legítima', 'Fraude'])

# Densidade cumulativa
plt.subplot(2, 2, 3)
for fraud in [0, 1]:
    subset = df[df['isFraud'] == fraud]
    sns.ecdfplot(data=subset, x='amount', label='Fraude' if fraud else 'Legítima')
plt.xscale('log')
plt.title('Função de Distribuição Cumulativa (CDF)')
plt.xlabel('Valor (log)')
plt.ylabel('Proporção acumulada')

# Violin plot
plt.subplot(2, 2, 4)
sns.violinplot(data=df[df['amount'] < df['amount'].quantile(0.95)], x='isFraud', y='amount', cut=0)
plt.title('Densidade de Probabilidade')
plt.xticks([0, 1], ['Legítima', 'Fraude'])

plt.tight_layout()
plt.show()

# %% [markdown]
# ##  Análise de Limiares de Valor para Detecção

# %%
# Calculando pontos de corte ótimos
from sklearn.metrics import roc_curve

fpr, tpr, thresholds = roc_curve(df['isFraud'], df['amount'])
optimal_idx = np.argmax(tpr - fpr)
optimal_threshold = thresholds[optimal_idx]

print(f"\nLimiar ótimo para detecção: ${optimal_threshold:,.2f}")

# Matriz de confusão simplificada
print("\nEficiência em diferentes limiares:")
thresholds_to_test = [100000, 250000, 500000, 1000000]
for threshold in thresholds_to_test:
    fraud_above = len(df[(df['amount'] >= threshold) & (df['isFraud'] == 1)])
    legit_above = len(df[(df['amount'] >= threshold) & (df['isFraud'] == 0)])
    print(f"> ${threshold:,}: {fraud_above} fraudes capturadas (+{legit_above} legítimas)")
# Out:
# Limiar ótimo para detecção: $325,242.69
#
# Eficiência em diferentes limiares:
# > $100,000: 6506 fraudes capturadas (+2830858 legítimas)
# > $250,000: 5097 fraudes capturadas (+1242386 legítimas)
# > $500,000: 3864 fraudes capturadas (+336420 legítimas)
# > $1,000,000: 2706 fraudes capturadas (+127920 legítimas)

# %% [markdown]
# ## Análise Combinada com Tipos de Transação

# %%
# Valores médios por tipo e status de fraude
plt.figure(figsize=(12, 6))
sns.barplot(data=df, x='type', y='amount', hue='isFraud', estimator=np.median, 
            errorbar=None, palette=['blue', 'red'])
plt.yscale('log')
plt.title('Valor Mediano por Tipo de Transação e Status de Fraude')
plt.ylabel('Valor Mediano (log scale)')
plt.xlabel('Tipo de Transação')
plt.legend(title='É Fraude?')
plt.show()

# Top 5 combinações tipo/valor mais suspeitas
fraud_patterns = df[df['isFraud'] == 1].groupby(['type', 'amount_category']).size().nlargest(5)
print("\nPadrões mais comuns de fraude (tipo + faixa de valor):")
print(fraud_patterns)
# Out:
# Padrões mais comuns de fraude (tipo + faixa de valor):
# type      amount_category
# TRANSFER  >100k              3255
# CASH_OUT  >100k              3251
#           10k-100k            718
# TRANSFER  10k-100k            711
# CASH_OUT  1k-10k              110
# dtype: int64
# C:\Users\user\AppData\Local\Temp\ipykernel_11420\257901845.py:13: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   fraud_patterns = df[df['isFraud'] == 1].groupby(['type', 'amount_category']).size().nlargest(5)

# %%
df['value_balance_ratio'] = df['amount'] / (df['oldbalanceOrg'] + 1)
high_ratio = df['value_balance_ratio'] > 0.9
print(f"\nTransações >90% do saldo: {high_ratio.sum()} casos ({high_ratio.mean()*100:.2f}% do total)")
# Out:
# Transações >90% do saldo: 4138310 casos (65.04% do total)

# %%
# Razão entre valor da transação e saldo inicial
df['amount_balance_ratio'] = df['amount'] / (df['oldbalanceOrg'] + 0.01)  # +0.01 para evitar divisão por zero

plt.figure(figsize=(12, 6))
sns.boxplot(data=df[(df['amount_balance_ratio'] < 10) & (df['amount_balance_ratio'] > 0)], 
            x='isFraud', y='amount_balance_ratio', showfliers=False)
plt.title('Razão entre Valor da Transação e Saldo Inicial')
plt.xticks([0, 1], ['Legítima', 'Fraude'])
plt.ylabel('Valor/Saldo')
plt.show()

# %%
# Média móvel de valores fraudulentos ao longo do tempo
fraud_ts = df[df['isFraud'] == 1].groupby('step')['amount'].mean().rolling(window=24).mean()

plt.figure(figsize=(12, 6))
fraud_ts.plot()
plt.title('Média Móvel (24h) do Valor de Transações Fraudulentas')
plt.xlabel('Step (hora)')
plt.ylabel('Valor Médio')
plt.grid(True)
plt.show()

# %%
# adas

# %%
# Relação entre valor e tipo de transação
plt.figure(figsize=(12, 6))
sns.boxplot(data=df[df['amount'] < df['amount'].quantile(0.99)], 
            x='type', y='amount', hue='isFraud', showfliers=False)
plt.yscale('log')
plt.title('Distribuição de Valores por Tipo de Transação e Status de Fraude')
plt.ylabel('Valor (log scale)')
plt.legend(title='É Fraude?')
plt.show()

# %%
# Matriz de correlação
plt.figure(figsize=(10, 8))
corr_matrix = df.corr(numeric_only=True)
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Matriz de Correlação')
plt.show()

# Correlação específica com isFraud
print("\n" + "="*50)
print("Correlação com a variável isFraud:")
print(corr_matrix['isFraud'].sort_values(ascending=False))
# Out:
# ...
# Correlação com a variável isFraud:
# isFraud                1.000000
# amount                 0.076688
# step                   0.031578
# balance_change_dest    0.027028
# oldbalanceOrg          0.010154
# newbalanceDest         0.000535
# oldbalanceDest        -0.005885
# newbalanceOrig        -0.008148
# balance_change_orig   -0.362472
# Name: isFraud, dtype: float64
